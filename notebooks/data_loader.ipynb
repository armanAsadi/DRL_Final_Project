# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
src_path = str(project_root / "src")

# %% [markdown]
# # Data Collection
#
# In this notebook, we collect historical daily market data for the 30 companies included in the Dow Jones Industrial Average (DJIA).
#
# The data is downloaded directly from Yahoo Finance using the `yfinance` package and stored locally for future use. If the dataset already exists on disk, it is loaded without downloading it again.
#
# This notebook verifies that the downloaded dataset is complete and correctly formatted before proceeding to the preprocessing stage.

# %%
from utils import create_directories
from data_loader import DataLoader

create_directories()

loader = DataLoader()

df = loader.get_data()

df.head()
# Out:
# ...
# [*********************100%***********************]  30 of 30 completed
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.406481  493729600
# 1 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.417559  601904800
# 2 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.315477  552160000
# 3 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.303802  477131200
# 4 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.345710  447610800
#
#   Ticker
# 0   AAPL
# 1   AAPL
# 2   AAPL
# 3   AAPL
# 4   AAPL

# %% [markdown]
# ## Dataset Overview
#
# The following checks verify the integrity of the downloaded dataset:
#
# - Dataset dimensions
# - Data types
# - Missing values
# - Number of unique stocks
# - Date range

# %%
print(df.shape)

print(df.dtypes)

print(df["Ticker"].nunique())

print(df["Date"].min())

print(df["Date"].max())

df.isna().sum()
# Out:
# (113190, 8)
# Date         datetime64[s]
# Open               float64
# High               float64
# Low                float64
# Close              float64
# Adj Close          float64
# Volume               int64
# Ticker                 str
# dtype: object
# 30
# 2010-01-04 00:00:00
# 2024-12-30 00:00:00
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Ticker       0
# dtype: int64

# %%
df.groupby("Ticker").size()
# Out:
# Ticker
# AAPL    3773
# AMGN    3773
# AMZN    3773
# AXP     3773
# BA      3773
# CAT     3773
# CRM     3773
# CSCO    3773
# CVX     3773
# DIS     3773
# GS      3773
# HD      3773
# HON     3773
# IBM     3773
# JNJ     3773
# JPM     3773
# KO      3773
# MCD     3773
# MMM     3773
# MRK     3773
# MSFT    3773
# NKE     3773
# PG      3773
# SHW     3773
# TRV     3773
# UNH     3773
# V       3773
# VZ      3773
# WMT     3773
# XOM     3773
# dtype: int64
